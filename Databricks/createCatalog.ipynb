# %% [markdown]
# # Create Catalog

# %%
# %sql
create catalog carSalesCatalog

# %% [markdown]
# # Create Silver Schema

# %%
# %sql
create schema carsalescatalog.silver

# %% [markdown]
# # Create Gold Schema

# %%
# %sql
create schema carsalescatalog.gold
